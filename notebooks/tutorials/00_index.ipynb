# %% [markdown]
# # PDESolve executable tutorials
#
# These notebooks mirror the worked-example families. They are intended to be read in order, but each is self-contained and executable from a source checkout.| # | Notebook | Mathematical focus ||---|---|---|| 1 | `01_linear_first_order.ipynb` | characteristic transport || 2 | `02_nonlinear_first_order.ipynb` | implicit characteristics || 3 | `03_conservation_laws.ipynb` | shocks, weak solutions, entropy || 4 | `04_heat_equations.ipynb` | Fourier/eigenfunction heat series || 5 | `05_wave_equations.ipynb` | d’Alembert propagation || 6 | `06_elliptic_separation.ipynb` | rectangular Laplace separation || 7 | `07_constant_coefficient.ipynb` | operator algebra and resonance || 8 | `08_transform_methods.ipynb` | unified transform and dispersion || 9 | `09_hyperbolic_systems.ipynb` | matrix characteristics || 10 | `10_symmetry_reduction.ipynb` | invariants and reduction || 11 | `11_kernels_green.ipynb` | fundamental solutions / Green kernels |The tutorials intentionally show both **PDESolve's own verification metadata** and **independent mathematical checks**. They do not claim capabilities beyond the cases supported by the package and test suite.
